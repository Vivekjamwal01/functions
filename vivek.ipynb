# %% [markdown]
# # Functions

# %% [markdown]
# 1. what is the python?
#    - fsvregwrtbrt sfbafb sbffsb sbbsrb.
# 2. qevqrev
#    - vqrev

# %%
# question

'''
this is code
'''
# Out:
# '\nthis is code\n'
